# %%
import pandas as pd

# %%
# example ride data
ride_data = pd.read_csv('mad_tea_party.csv')
ride_data
# Out:
#               date             datetime  SACTMIN  SPOSTMIN
# 0       01/01/2015  2015-01-01 07:37:12      NaN       5.0
# 1       01/01/2015  2015-01-01 07:44:12      NaN       5.0
# 2       01/01/2015  2015-01-01 07:51:12      NaN       5.0
# 3       01/01/2015  2015-01-01 09:09:16      NaN       5.0
# 4       01/01/2015  2015-01-01 09:16:12      NaN       5.0
# ...            ...                  ...      ...       ...
# 303941  12/28/2021  2021-12-28 22:35:34      NaN       5.0
# 303942  12/28/2021  2021-12-28 22:42:15      NaN       5.0
# 303943  12/28/2021  2021-12-28 22:48:12      NaN       5.0
# 303944  12/28/2021  2021-12-28 22:54:10      NaN       5.0
# 303945  12/28/2021  2021-12-28 23:00:27      NaN       5.0
#
# [303946 rows x 4 columns]

# %%
park_metadata = pd.read_csv('park_metadata.csv')
# check that dates are unique
#len(park_metadata) == len(list(set(park_metadata['DATE'])))
# Out:
#                                          Ride_name Park_location  \
# 0                           Alien Swirling Saucers            HS
# 1                                    Astro Orbiter            MK
# 2                         Avatar Flight of Passage            AK
# 3                    Big Thunder Mountain Railroad            MK
# 4               Buzz Lightyear's Space Ranger Spin            MK
# 5                                         Dinosaur            AK
# 6                        Dumbo the Flying Elephant            MK
# 7                               Expedition Everest            AK
# 8                                Frozen Ever After            EC
# 9   Gran Fiesta Tour Starring The Three Caballeros            EC
# 10                                 Haunted Mansion            MK
# 11                              It's a Small World            MK
# 12           Journey Into Imagination with Figment            EC
# ...

# %%
park_metadata
# Out:
#             DATE WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  \
# 0     01/01/2015               NaN          5          0           0
# 1     01/02/2015               NaN          6          1           0
# 2     01/03/2015               NaN          7          2           0
# 3     01/04/2015               NaN          1          3           1
# 4     01/05/2015               NaN          2          4           1
# ...          ...               ...        ...        ...         ...
# 2074  08/27/2021               NaN          6        238          34
# 2075  08/28/2021               NaN          7        239          34
# 2076  08/29/2021               NaN          1        240          35
# 2077  08/30/2021               NaN          2        241          35
# 2078  08/31/2021               NaN          3        242          35
#
#       MONTHOFYEAR  YEAR          SEASON  HOLIDAYPX  HOLIDAYM  ... HSFIREWKS  \
# ...

# %%
ride_data['DATE'] = ride_data['date']

# %%
merge_data = pd.merge(ride_data, park_metadata, how = 'inner', on = 'DATE')
merge_data
# Out:
#               date             datetime  SACTMIN  SPOSTMIN        DATE  \
# 0       01/01/2015  2015-01-01 07:37:12      NaN       5.0  01/01/2015
# 1       01/01/2015  2015-01-01 07:44:12      NaN       5.0  01/01/2015
# 2       01/01/2015  2015-01-01 07:51:12      NaN       5.0  01/01/2015
# 3       01/01/2015  2015-01-01 09:09:16      NaN       5.0  01/01/2015
# 4       01/01/2015  2015-01-01 09:16:12      NaN       5.0  01/01/2015
# ...            ...                  ...      ...       ...         ...
# 266936  08/31/2021  2021-08-31 20:47:24      NaN       5.0  08/31/2021
# 266937  08/31/2021  2021-08-31 20:54:12      NaN       5.0  08/31/2021
# 266938  08/31/2021  2021-08-31 21:00:17      NaN       5.0  08/31/2021
# 266939  08/31/2021  2021-08-31 21:01:11      NaN    -999.0  08/31/2021
# 266940  08/31/2021  2021-08-31 21:12:17      NaN    -999.0  08/31/2021
#
#        WDW_TICKET_SEASON  DAYOFWEEK  DAYOFYEAR  WEEKOFYEAR  MONTHOFYEAR  ...  \
# ...

# %%
merge_data = merge_data.drop(columns = ['DATE'])
merge_data
# Out:
#               date             datetime  SACTMIN  SPOSTMIN WDW_TICKET_SEASON  \
# 0       01/01/2015  2015-01-01 07:37:12      NaN       5.0               NaN
# 1       01/01/2015  2015-01-01 07:44:12      NaN       5.0               NaN
# 2       01/01/2015  2015-01-01 07:51:12      NaN       5.0               NaN
# 3       01/01/2015  2015-01-01 09:09:16      NaN       5.0               NaN
# 4       01/01/2015  2015-01-01 09:16:12      NaN       5.0               NaN
# ...            ...                  ...      ...       ...               ...
# 266936  08/31/2021  2021-08-31 20:47:24      NaN       5.0               NaN
# 266937  08/31/2021  2021-08-31 20:54:12      NaN       5.0               NaN
# 266938  08/31/2021  2021-08-31 21:00:17      NaN       5.0               NaN
# 266939  08/31/2021  2021-08-31 21:01:11      NaN    -999.0               NaN
# 266940  08/31/2021  2021-08-31 21:12:17      NaN    -999.0               NaN
#
# ...
